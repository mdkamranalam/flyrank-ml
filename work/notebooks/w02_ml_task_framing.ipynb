# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/mdkamranalam/flyrank-ml-week-01/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
# This cell is for CODE (numbers, a query, a check).
task_type = "Ranking / scoring"
print(f"Chosen ML Task Type: {task_type}")
# Out:
# Chosen ML Task Type: Ranking / scoring

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
# Check the target distribution in starter data
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# Read directly from your GitHub repository so Colab can see it
url = 'https://raw.githubusercontent.com/mdkamranalam/flyrank-ml-week-01/main/data/raw/content_refresh_anonymized.csv'
df = pd.read_csv(url)

is_declining = (df['trend_direction'] == 'down')
print("Target proxy distribution (is_declining_label):")
print(is_declining.value_counts(normalize=True).round(3))
# Out:
# Target proxy distribution (is_declining_label):
# trend_direction
# True     0.542
# False    0.458
# Name: proportion, dtype: float64

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
# This cell is for CODE (numbers, a query, a check).
success_metric = "Precision@50"
print(f"Success Metric: {success_metric}")
# Out:
# Success Metric: Precision@50

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
# Load the starter data to show the unit of analysis
url = 'https://raw.githubusercontent.com/mdkamranalam/flyrank-ml-week-01/main/data/raw/content_refresh_anonymized.csv'
df = pd.read_csv(url)
print(f"Dataset shape: {df.shape}")
df.head(3)
# Out:
# Dataset shape: (30000, 44)
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# 0     20457.0  ...     15000-25000  0.76          10.6             5.88
# 1     15562.0  ...     15000-25000  0.05          20.3             0.00
# 2     23643.0  ...     15000-25000  0.09          36.5             0.00
#
#    scroll_rate  ai_traffic_pct  impression_tier  position_tier  \
# ...

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Show how many distinct features we have available to build a model vs a simple rule
print(f"Total features available for ML model to capture non-linear patterns: {df.shape[1]}")
# Out:
# Total features available for ML model to capture non-linear patterns: 44

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
